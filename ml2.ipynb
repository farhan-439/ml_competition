# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("submission.csv")

# Lowercase the column names
df.columns = df.columns.str.lower()

# (Optional) Save the modified CSV
df.to_csv("file_lowercase.csv", index=False)
